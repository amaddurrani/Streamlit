# %% [markdown]
# <center><font size="16">**Titanic: Machine Learning from Disaster**</font></center>

# %% [markdown]
# The sinking of the RMS Titanic is one of the most infamous shipwrecks in history.  On April 15, 1912, during her maiden voyage, the Titanic sank after colliding with an iceberg, killing 1502 out of 2224 passengers and crew. This sensational tragedy shocked the international community and led to better safety regulations for ships.
#
# One of the reasons that the shipwreck led to such loss of life was that there were not enough lifeboats for the passengers and crew. Although there was some element of luck involved in surviving the sinking, some groups of people were more likely to survive than others, such as women, children, and the upper-class.
#
# In this notebook, we will see how to dig deep into the data and visualize it.
#
# #### https://seaborn.pydata.org/generated/seaborn.countplot.html

# %% [markdown]
#  [![TITANIC sinking](https://i.imgur.com/8Rmg0vy.jpg)](https://youtu.be/9xoqXVjBEF8 "TITANIC sinking")

# %% [markdown]
# ### Data

# %% [markdown]
# The data has been split into two groups:
#
# - titanic data (titanic_data.csv)
# - competition data (competition.csv)
#
# The tasks given to you will be performed on "competition.csv"

# %% [markdown]
# ### Data Dictionary

# %% [markdown]
# <center>
# <table class="table table-bordered">
# <tr>
# <th style="width:5%">Variable</th><th style="width:5%">Definition</th><th style="width:5%">Key</th>
# </tr>
# <tr>
# <td>survival</td>
# <td>Survival</td>
# <td>0 = No, 1 = Yes</td>
# </tr>
# <tr>
# <td>pclass</td>
# <td>Ticket class</td>
# <td>1 = 1st, 2 = 2nd, 3 = 3rd</td>
# </tr>
# <tr>
# <td>sex</td>
# <td>sex</td>
# <td></td>
# </tr>
# <tr>
# <td>Age</td>
# <td>Age in years</td>
# <td></td>
# </tr>
# <tr>
# <td>sibsp</td>
# <td># of siblings / spouses aboard the Titanic</td>
# <td></td>
# </tr>
# <tr>
# <td>parch</td>
# <td># of parents / children aboard the Titanic</td>
# <td></td>
# </tr>
# <tr>
# <td>ticket</td>
# <td>Ticket number</td>
# <td></td>
# </tr>
# <tr>
# <td>fare</td>
# <td>Passenger fare</td>
# <td></td>
# </tr>
# <tr>
# <td>cabin</td>
# <td>Cabin number</td>
# <td></td>
# </tr>
# <tr>
# <td>embarked</td>
# <td>Port of Embarkation</td>
# <td>C = Cherbourg, Q = Queenstown, S = Southampton</td>
# </tr>
# </table>
# </center>

# %% [markdown]
# # Wrangling & EDA

# %% [markdown]
# ## 1. Loading Packages

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()
# %matplotlib inline

# %% [markdown]
# ## 2. Loading Data & Basic Analysis

# %%
data = pd.read_csv('titanic_data.csv')
dftitanic = data.copy()

# %%
data
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch            Ticket     Fare Cabin Embarked
# 0        0         A/5 21171   7.2500   NaN        S
# 1        0          PC 17599  71.2833   C85        C
# 2        0  STON/O2. 3101282   7.9250   NaN        S
# 3        0            113803  53.1000  C123        S
# 4        0            373450   8.0500   NaN        S
# ..     ...               ...      ...   ...      ...
# 886      0            211536  13.0000   NaN        S
# 887      0            112053  30.0000   B42        S
# 888      2        W./C. 6607  23.4500   NaN        S
# 889      0            111369  30.0000  C148        C
# 890      0            370376   7.7500   NaN        Q
#
# [891 rows x 12 columns]

# %% [markdown]
# ### Task 1
# Import the competition file and copy it

# %%
#Write the code here
#data_comp = 
#dfcomp =

# %% [markdown]
# ### Basic Structure

# %%
dftitanic.shape
# Out:
# (891, 12)

# %% [markdown]
# **Task 2:**
# Find the shape of 'dfcomp'

# %%
#Write code here

# %%
dftitanic.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked
# 0      0         A/5 21171   7.2500   NaN        S
# 1      0          PC 17599  71.2833   C85        C
# 2      0  STON/O2. 3101282   7.9250   NaN        S
# 3      0            113803  53.1000  C123        S
# 4      0            373450   8.0500   NaN        S

# %%
dftitanic.tail(10)
# Out:
#      PassengerId  Survived  Pclass                                      Name  \
# 881          882         0       3                        Markun, Mr. Johann
# 882          883         0       3              Dahlberg, Miss. Gerda Ulrika
# 883          884         0       2             Banfield, Mr. Frederick James
# 884          885         0       3                    Sutehall, Mr. Henry Jr
# 885          886         0       3      Rice, Mrs. William (Margaret Norton)
# 886          887         0       2                     Montvila, Rev. Juozas
# 887          888         1       1              Graham, Miss. Margaret Edith
# 888          889         0       3  Johnston, Miss. Catherine Helen "Carrie"
# 889          890         1       1                     Behr, Mr. Karl Howell
# 890          891         0       3                       Dooley, Mr. Patrick
#
#         Sex   Age  SibSp  Parch            Ticket     Fare Cabin Embarked
# 881    male  33.0      0      0            349257   7.8958   NaN        S
# 882  female  22.0      0      0              7552  10.5167   NaN        S
# 883    male  28.0      0      0  C.A./SOTON 34068  10.5000   NaN        S
# 884    male  25.0      0      0   SOTON/OQ 392076   7.0500   NaN        S
# 885  female  39.0      0      5            382652  29.1250   NaN        Q
# 886    male  27.0      0      0            211536  13.0000   NaN        S
# 887  female  19.0      0      0            112053  30.0000   B42        S
# 888  female   NaN      1      2        W./C. 6607  23.4500   NaN        S
# 889    male  26.0      0      0            111369  30.0000  C148        C
# 890    male  32.0      0      0            370376   7.7500   NaN        Q

# %% [markdown]
# **Task 3:**
# Head for 'dfcomp'

# %%
#Write code here

# %%
dftitanic.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %% [markdown]
# **Task 4:**
# Find datatypes for dfcomp

# %%
#Write code here

# %%
dftitanic.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   891.000000  891.000000  891.000000  714.000000  891.000000
# mean    446.000000    0.383838    2.308642   29.699118    0.523008
# std     257.353842    0.486592    0.836071   14.526497    1.102743
# min       1.000000    0.000000    1.000000    0.420000    0.000000
# 25%     223.500000    0.000000    2.000000   20.125000    0.000000
# 50%     446.000000    0.000000    3.000000   28.000000    0.000000
# 75%     668.500000    1.000000    3.000000   38.000000    1.000000
# max     891.000000    1.000000    3.000000   80.000000    8.000000
#
#             Parch        Fare
# count  891.000000  891.000000
# mean     0.381594   32.204208
# std      0.806057   49.693429
# min      0.000000    0.000000
# 25%      0.000000    7.910400
# 50%      0.000000   14.454200
# 75%      0.000000   31.000000
# max      6.000000  512.329200

# %%
dftitanic.describe(include=["O"])
# Out:
#                            Name   Sex  Ticket    Cabin Embarked
# count                       891   891     891      204      889
# unique                      891     2     681      147        3
# top     Braund, Mr. Owen Harris  male  347082  B96 B98        S
# freq                          1   577       7        4      644

# %%
dftitanic.describe(include='all')
# Out:
#         PassengerId    Survived      Pclass                     Name   Sex  \
# count    891.000000  891.000000  891.000000                      891   891
# unique          NaN         NaN         NaN                      891     2
# top             NaN         NaN         NaN  Braund, Mr. Owen Harris  male
# freq            NaN         NaN         NaN                        1   577
# mean     446.000000    0.383838    2.308642                      NaN   NaN
# std      257.353842    0.486592    0.836071                      NaN   NaN
# min        1.000000    0.000000    1.000000                      NaN   NaN
# 25%      223.500000    0.000000    2.000000                      NaN   NaN
# 50%      446.000000    0.000000    3.000000                      NaN   NaN
# 75%      668.500000    1.000000    3.000000                      NaN   NaN
# max      891.000000    1.000000    3.000000                      NaN   NaN
#
#                Age       SibSp       Parch  Ticket        Fare    Cabin  \
# count   714.000000  891.000000  891.000000     891  891.000000      204
# unique         NaN         NaN         NaN     681         NaN      147
# top            NaN         NaN         NaN  347082         NaN  B96 B98
# freq           NaN         NaN         NaN       7         NaN        4
# mean     29.699118    0.523008    0.381594     NaN   32.204208      NaN
# std      14.526497    1.102743    0.806057     NaN   49.693429      NaN
# min       0.420000    0.000000    0.000000     NaN    0.000000      NaN
# 25%      20.125000    0.000000    0.000000     NaN    7.910400      NaN
# 50%      28.000000    0.000000    0.000000     NaN   14.454200      NaN
# 75%      38.000000    1.000000    0.000000     NaN   31.000000      NaN
# max      80.000000    8.000000    6.000000     NaN  512.329200      NaN
#
#        Embarked
# count       889
# unique        3
# top           S
# freq        644
# mean        NaN
# std         NaN
# min         NaN
# 25%         NaN
# 50%         NaN
# 75%         NaN
# max         NaN

# %% [markdown]
# **Task 5:**
# Describe statistics for 'dfcomp'

# %%
#Write code here

# %% [markdown]
# ### Completeness

# %%
dftitanic.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %% [markdown]
# **Task 6:**
# Check completeness for 'dfcomp'

# %%
#Write code here

# %% [markdown]
# ## 3. Exploration

# %% [markdown]
# ### 3.1 Exploration of Complete & Important Variables
#
# Our response variable in the training set is complete, as well as Sex and Pclass, which seem two of the most important predictors.

# %% [markdown]
# **Survival**

# %%
sns.countplot(x='Survived', hue='Survived', data=dftitanic);

# %% [markdown]
# **Gender & Survival**

# %%
sns.countplot(x='Sex', data=dftitanic)
# Out:
# <Axes: xlabel='Sex', ylabel='count'>

# %%
sns.countplot(x='Sex', hue='Sex', data=dftitanic)
# Out:
# <Axes: xlabel='Sex', ylabel='count'>

# %%
sns.countplot(x='Survived', hue='Sex', data=dftitanic)
# Out:
# <Axes: xlabel='Survived', ylabel='count'>

# %% [markdown]
# **Task 7:**
# Make a count plot for gender using 'dfcomp'

# %%
#Write code here

# %% [markdown]
# ### Passenger Survival Class

# %%
sns.countplot(x='Pclass', data=dftitanic);

# %% [markdown]
# **Task 8:**
# Make a count plot for 'pclass' using 'dfcomp'

# %%
#Write code here

# %%
sns.countplot(x='Pclass', hue='Survived', data=dftitanic);

# %% [markdown]
# **Passenger Class, Gender & Survival**

# %% [markdown]
# ## count gender wise servival rate w.r.t pclass?

# %%
sns.catplot(x='Sex', hue='Survived', col='Pclass', data=dftitanic,kind='count')

# %% [markdown]
# **Task 9:**
# Make factor plot using dfcomp for gender, pclass and their count

# %%
# Write code here

# %% [markdown]
# ### 3.2 What's in the name?

# %%
dftitanic['Name'].head(10)
# Out:
# 0                              Braund, Mr. Owen Harris
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...
# 2                               Heikkinen, Miss. Laina
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)
# 4                             Allen, Mr. William Henry
# 5                                     Moran, Mr. James
# 6                              McCarthy, Mr. Timothy J
# 7                       Palsson, Master. Gosta Leonard
# 8    Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)
# 9                  Nasser, Mrs. Nicholas (Adele Achem)
# Name: Name, dtype: object

# %% [markdown]
# **Extracting & Analyzing Titles**

# %% [markdown]
# This is called feature engineering where you derive additional columns as per your domain knowledge like creating 'Title in the following example.

# %%
import re 
a='Braund, Mr.Owen Harris'
re.search(' ([A-Z][a-z]+)\.', a).group(1)
# Out:
# 'Mr'

# %%
dftitanic['Title'] = dftitanic['Name'].apply(lambda x: re.search('([A-Z][a-z]+)\.', x).group(1))
dftitanic.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked Title
# 0      0         A/5 21171   7.2500   NaN        S    Mr
# 1      0          PC 17599  71.2833   C85        C   Mrs
# 2      0  STON/O2. 3101282   7.9250   NaN        S  Miss
# 3      0            113803  53.1000  C123        S   Mrs
# 4      0            373450   8.0500   NaN        S    Mr

# %%
dftitanic.groupby(['Sex']).count()
# Out:
#         PassengerId  Survived  Pclass  Name  Age  SibSp  Parch  Ticket  Fare  \
# Sex
# female          314       314     314   314  261    314    314     314   314
# male            577       577     577   577  453    577    577     577   577
#
#         Cabin  Embarked  Title
# Sex
# female     97       312    314
# male      107       577    577

# %%
dftitanic['Title'].value_counts()
# Out:
# Title
# Mr          517
# Miss        182
# Mrs         125
# Master       40
# Dr            7
# Rev           6
# Mlle          2
# Major         2
# Col           2
# Countess      1
# Capt          1
# Ms            1
# Sir           1
# Lady          1
# Mme           1
# Don           1
# Jonkheer      1
# Name: count, dtype: int64

# %% [markdown]
# **Taks 10:**
# Find the titles for dfcomp

# %%
# Write code here

# %% [markdown]
# **Task 11:**
# Display the count for title in dfcomp

# %%
# Write the code here

# %% [markdown]
# The term *Mademoiselle* is a French familiar title, abbreviated **Mlle**, traditionally given to an unmarried woman. The equivalent in English is "Miss". However, the courtesy title "Madame" is accorded women where their marital status is unknown.

# %%
dftitanic['Title'] = dftitanic['Title'].replace('Mlle', 'Miss')

# %% [markdown]
# In France, one traditionally calls a young, unmarried woman Mademoiselle – Mlle for short – and an older, married woman _Madame_, whose abbreviation is **Mme**.

# %%
dftitanic['Title'] = dftitanic['Title'].replace('Mme', 'Mrs')

# %%
dftitanic.loc[(~dftitanic['Title'].isin(['Mr', 'Mrs', 'Miss', 'Master'])), 'Title'] = 'Rare Title'

# %%
dftitanic['Title'].unique()
# Out:
# array(['Mr', 'Mrs', 'Miss', 'Master', 'Rare Title'], dtype=object)

# %%
sns.countplot(data=dftitanic,x='Title', hue='Survived')
# Out:
# <Axes: xlabel='Title', ylabel='count'>

# %% [markdown]
# **Task 12:**
# Assigning the remaining titles as 'Rare Title' in dfcomp

# %%
#Write the code here

# %% [markdown]
# ### 3.3 Travelling Alone vs. Travelling in groups

# %% [markdown]
# **3.3.1 Family Size**

# %%
dftitanic
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch            Ticket     Fare Cabin Embarked       Title
# 0        0         A/5 21171   7.2500   NaN        S          Mr
# 1        0          PC 17599  71.2833   C85        C         Mrs
# 2        0  STON/O2. 3101282   7.9250   NaN        S        Miss
# 3        0            113803  53.1000  C123        S         Mrs
# 4        0            373450   8.0500   NaN        S          Mr
# ..     ...               ...      ...   ...      ...         ...
# 886      0            211536  13.0000   NaN        S  Rare Title
# 887      0            112053  30.0000   B42        S        Miss
# 888      2        W./C. 6607  23.4500   NaN        S        Miss
# 889      0            111369  30.0000  C148        C          Mr
# 890      0            370376   7.7500   NaN        Q          Mr
#
# [891 rows x 13 columns]

# %%
dftitanic['Fsize'] = dftitanic['SibSp'] + dftitanic['Parch']+1

# %%
dftitanic
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# 886                              Montvila, Rev. Juozas    male  27.0      0
# 887                       Graham, Miss. Margaret Edith  female  19.0      0
# 888           Johnston, Miss. Catherine Helen "Carrie"  female   NaN      1
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch            Ticket     Fare Cabin Embarked       Title  Fsize
# 0        0         A/5 21171   7.2500   NaN        S          Mr      2
# 1        0          PC 17599  71.2833   C85        C         Mrs      2
# 2        0  STON/O2. 3101282   7.9250   NaN        S        Miss      1
# 3        0            113803  53.1000  C123        S         Mrs      2
# 4        0            373450   8.0500   NaN        S          Mr      1
# ..     ...               ...      ...   ...      ...         ...    ...
# 886      0            211536  13.0000   NaN        S  Rare Title      1
# 887      0            112053  30.0000   B42        S        Miss      1
# 888      2        W./C. 6607  23.4500   NaN        S        Miss      4
# 889      0            111369  30.0000  C148        C          Mr      1
# 890      0            370376   7.7500   NaN        Q          Mr      1
#
# [891 rows x 14 columns]

# %% [markdown]
# **Task 13:**
# Show the countplot on column **'Fsize'** and check how many people are survived and died.

# %%
# Write the code here
sns.countplot(x='Fsize', hue='Survived', data=dftitanic);

# %%
dftitanic.groupby('Fsize')['Survived'].value_counts(normalize=True).reset_index(name='perc')
# Out:
#     Fsize  Survived      perc
# 0       1         0  0.696462
# 1       1         1  0.303538
# 2       2         1  0.552795
# 3       2         0  0.447205
# 4       3         1  0.578431
# 5       3         0  0.421569
# 6       4         1  0.724138
# 7       4         0  0.275862
# 8       5         0  0.800000
# 9       5         1  0.200000
# 10      6         0  0.863636
# 11      6         1  0.136364
# 12      7         0  0.666667
# 13      7         1  0.333333
# 14      8         0  1.000000
# 15     11         0  1.000000

# %%
temp = dftitanic.groupby('Fsize')['Survived'].value_counts(normalize=True).reset_index(name='Perc')

plt.figure(figsize=(15,6))
sns.barplot(data=temp,x='Fsize', y='Perc', hue='Survived', dodge=True)
# Out:
# <Axes: xlabel='Fsize', ylabel='Perc'>

# %% [markdown]
# **3.3.2 How many people booked together?**
#
# _Apart from families, there could be groups of friends travelling together._

# %%
dftitanic['Ticket']
# Out:
# 0             A/5 21171
# 1              PC 17599
# 2      STON/O2. 3101282
# 3                113803
# 4                373450
#              ...
# 886              211536
# 887              112053
# 888          W./C. 6607
# 889              111369
# 890              370376
# Name: Ticket, Length: 891, dtype: object

# %%
dftitanic['Ticket'].value_counts().head()
# Out:
# Ticket
# 347082      7
# CA. 2343    7
# 1601        7
# 3101295     6
# CA 2144     6
# Name: count, dtype: int64

# %% [markdown]
# **reset_index()** is a method to reset index of a Data Frame. **reset_index()** method sets a list of integer ranging from 0 to length of data as index.

# %%
dftitanic['Ticket'].value_counts().reset_index().head()
# Out:
#      Ticket  count
# 0    347082      7
# 1  CA. 2343      7
# 2      1601      7
# 3   3101295      6
# 4   CA 2144      6

# %%
Temp = dftitanic['Ticket'].value_counts().reset_index(name='Tsize')

# %%
dftitanic = dftitanic.merge(temp, left_on='Ticket', right_on='index',how='inner').drop('index', axis=1)
dftitanic.head()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# d:\python\EDA _ Seaborn\EDA SEABORN-1.ipynb Cell 92 line 1
# ----> <a href='vscode-notebook-cell:/d%3A/python/EDA%20_%20Seaborn/EDA%20SEABORN-1.ipynb#Y156sZmlsZQ%3D%3D?line=0'>1</a> dftitanic = dftitanic.merge(Temp, left_on='Ticket', right_index=True,how='inner').drop('index', axis=1)
#       <a href='vscode-notebook-cell:/d%3A/python/EDA%20_%20Seaborn/EDA%20SEABORN-1.ipynb#Y156sZmlsZQ%3D%3D?line=1'>2</a> dftitanic.head()
#
# File c:\Users\muhammad.amad\AppData\Local\anaconda3\Lib\site-packages\pandas\core\frame.py:10487, in DataFrame.merge(self, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#   10468 @Substitution("")
#   10469 @Appender(_merge_doc, indents=2)
#   10470 def merge(
#    (...)
#   10483     validate: MergeValidate | None = None,
#   10484 ) -> DataFrame:
#   10485     from pandas.core.reshape.merge import merge
# > 10487     return merge(
#   10488         self,
#   10489         right,
#   10490         how=how,
#   10491         on=on,
#   10492         left_on=left_on,
#   10493         right_on=right_on,
#   10494         left_index=left_index,
#   10495         right_index=right_index,
#   10496         sort=sort,
#   10497         suffixes=suffixes,
#   10498         copy=copy,
#   10499         indicator=indicator,
#   10500         validate=validate,
#   10501     )
#
# File c:\Users\muhammad.amad\AppData\Local\anaconda3\Lib\site-packages\pandas\core\reshape\merge.py:169, in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#     154     return _cross_merge(
#     155         left_df,
#     156         right_df,
#    (...)
#     166         copy=copy,
#     167     )
#     168 else:
# --> 169     op = _MergeOperation(
#     170         left_df,
#     171         right_df,
#     172         how=how,
#     173         on=on,
#     174         left_on=left_on,
#     175         right_on=right_on,
#     176         left_index=left_index,
#     177         right_index=right_index,
#     178         sort=sort,
#     179         suffixes=suffixes,
#     180         indicator=indicator,
#     181         validate=validate,
#     182     )
#     183     return op.get_result(copy=copy)
#
# File c:\Users\muhammad.amad\AppData\Local\anaconda3\Lib\site-packages\pandas\core\reshape\merge.py:804, in _MergeOperation.__init__(self, left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, indicator, validate)
#     800 self._validate_tolerance(self.left_join_keys)
#     802 # validate the merge keys dtypes. We may need to coerce
#     803 # to avoid incompatible dtypes
# --> 804 self._maybe_coerce_merge_keys()
#     806 # If argument passed to validate,
#     807 # check if columns specified as unique
#     808 # are in fact unique.
#     809 if validate is not None:
#
# File c:\Users\muhammad.amad\AppData\Local\anaconda3\Lib\site-packages\pandas\core\reshape\merge.py:1479, in _MergeOperation._maybe_coerce_merge_keys(self)
#    1473     # unless we are merging non-string-like with string-like
#    1474     elif (
#    1475         inferred_left in string_types and inferred_right not in string_types
#    1476     ) or (
#    1477         inferred_right in string_types and inferred_left not in string_types
#    1478     ):
# -> 1479         raise ValueError(msg)
#    1481 # datetimelikes must match exactly
#    1482 elif needs_i8_conversion(lk.dtype) and not needs_i8_conversion(rk.dtype):
#
# ValueError: You are trying to merge on object and int64 columns for key 'Ticket'. If you wish to proceed you should use pd.concat

# %%
temp.head()
# Out:
#      Ticket  Tsize
# 0    347082      7
# 1  CA. 2343      7
# 2      1601      7
# 3   3101295      6
# 4   CA 2144      6

# %%
dftitanic.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4            5         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                           Allen, Mr. William Henry    male  35.0      0
#
#    Parch            Ticket     Fare Cabin Embarked Title  Fsize
# 0      0         A/5 21171   7.2500   NaN        S    Mr      2
# 1      0          PC 17599  71.2833   C85        C   Mrs      2
# 2      0  STON/O2. 3101282   7.9250   NaN        S  Miss      1
# 3      0            113803  53.1000  C123        S   Mrs      2
# 4      0            373450   8.0500   NaN        S    Mr      1

# %%
dftitanic = dftitanic.merge(temp, left_on='Ticket', right_on='index',how='inner').drop('index', axis=1)
dftitanic.head()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# d:\python\EDA _ Seaborn\EDA SEABORN-1.ipynb Cell 95 line 1
# ----> <a href='vscode-notebook-cell:/d%3A/python/EDA%20_%20Seaborn/EDA%20SEABORN-1.ipynb#Y366sZmlsZQ%3D%3D?line=0'>1</a> dftitanic = dftitanic.merge(temp, left_on='Ticket', right_on='index',how='inner').drop('index', axis=1)
#       <a href='vscode-notebook-cell:/d%3A/python/EDA%20_%20Seaborn/EDA%20SEABORN-1.ipynb#Y366sZmlsZQ%3D%3D?line=1'>2</a> dftitanic.head()
#
# File c:\Users\muhammad.amad\AppData\Local\anaconda3\Lib\site-packages\pandas\core\frame.py:10487, in DataFrame.merge(self, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#   10468 @Substitution("")
#   10469 @Appender(_merge_doc, indents=2)
#   10470 def merge(
#    (...)
#   10483     validate: MergeValidate | None = None,
#   10484 ) -> DataFrame:
#   10485     from pandas.core.reshape.merge import merge
# > 10487     return merge(
#   10488         self,
#   10489         right,
#   10490         how=how,
#   10491         on=on,
#   10492         left_on=left_on,
#   10493         right_on=right_on,
#   10494         left_index=left_index,
#   10495         right_index=right_index,
#   10496         sort=sort,
#   10497         suffixes=suffixes,
#   10498         copy=copy,
#   10499         indicator=indicator,
#   10500         validate=validate,
#   10501     )
#
# File c:\Users\muhammad.amad\AppData\Local\anaconda3\Lib\site-packages\pandas\core\reshape\merge.py:169, in merge(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#     154     return _cross_merge(
#     155         left_df,
#     156         right_df,
#    (...)
#     166         copy=copy,
#     167     )
#     168 else:
# --> 169     op = _MergeOperation(
#     170         left_df,
#     171         right_df,
#     172         how=how,
#     173         on=on,
#     174         left_on=left_on,
#     175         right_on=right_on,
#     176         left_index=left_index,
#     177         right_index=right_index,
#     178         sort=sort,
#     179         suffixes=suffixes,
#     180         indicator=indicator,
#     181         validate=validate,
#     182     )
#     183     return op.get_result(copy=copy)
#
# File c:\Users\muhammad.amad\AppData\Local\anaconda3\Lib\site-packages\pandas\core\reshape\merge.py:791, in _MergeOperation.__init__(self, left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, indicator, validate)
#     781     raise MergeError(msg)
#     783 self.left_on, self.right_on = self._validate_left_right_on(left_on, right_on)
#     785 (
#     786     self.left_join_keys,
#     787     self.right_join_keys,
#     788     self.join_names,
#     789     left_drop,
#     790     right_drop,
# --> 791 ) = self._get_merge_keys()
#     793 if left_drop:
#     794     self.left = self.left._drop_labels_or_levels(left_drop)
#
# File c:\Users\muhammad.amad\AppData\Local\anaconda3\Lib\site-packages\pandas\core\reshape\merge.py:1269, in _MergeOperation._get_merge_keys(self)
#    1267 rk = cast(Hashable, rk)
#    1268 if rk is not None:
# -> 1269     right_keys.append(right._get_label_or_level_values(rk))
#    1270 else:
#    1271     # work-around for merge_asof(right_index=True)
#    1272     right_keys.append(right.index._values)
#
# File c:\Users\muhammad.amad\AppData\Local\anaconda3\Lib\site-packages\pandas\core\generic.py:1844, in NDFrame._get_label_or_level_values(self, key, axis)
#    1842     values = self.axes[axis].get_level_values(key)._values
#    1843 else:
# -> 1844     raise KeyError(key)
#    1846 # Check for duplicates
#    1847 if values.ndim > 1:
#
# KeyError: 'index'

# %% [markdown]
# **Task 14:**
# Show the countplot on column **'Tsize'** and check how many people are survived and died.

# %%
#write code here

# %%
temp = dftitanic.groupby('Tsize')['Survived'].value_counts(normalize=True).reset_index(name='Perc')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# d:\python\EDA _ Seaborn\EDA SEABORN-1.ipynb Cell 95 line 1
# ----> <a href='vscode-notebook-cell:/d%3A/python/EDA%20_%20Seaborn/EDA%20SEABORN-1.ipynb#Y162sZmlsZQ%3D%3D?line=0'>1</a> temp = dftitanic.groupby('Tsize')['Survived'].value_counts(normalize=True).reset_index(name='Perc')
#
# File c:\Users\muhammad.amad\AppData\Local\anaconda3\Lib\site-packages\pandas\core\frame.py:8869, in DataFrame.groupby(self, by, axis, level, as_index, sort, group_keys, observed, dropna)
#    8866 if level is None and by is None:
#    8867     raise TypeError("You have to supply one of 'by' and 'level'")
# -> 8869 return DataFrameGroupBy(
#    8870     obj=self,
#    8871     keys=by,
#    8872     axis=axis,
#    8873     level=level,
#    8874     as_index=as_index,
#    8875     sort=sort,
#    8876     group_keys=group_keys,
#    8877     observed=observed,
#    8878     dropna=dropna,
#    8879 )
#
# File c:\Users\muhammad.amad\AppData\Local\anaconda3\Lib\site-packages\pandas\core\groupby\groupby.py:1278, in GroupBy.__init__(self, obj, keys, axis, level, grouper, exclusions, selection, as_index, sort, group_keys, observed, dropna)
#    1275 self.dropna = dropna
#    1277 if grouper is None:
# -> 1278     grouper, exclusions, obj = get_grouper(
#    1279         obj,
#    1280         keys,
#    1281         axis=axis,
#    1282         level=level,
#    1283         sort=sort,
#    1284         observed=False if observed is lib.no_default else observed,
#    1285         dropna=self.dropna,
#    1286     )
#    1288 if observed is lib.no_default:
#    1289     if any(ping._passed_categorical for ping in grouper.groupings):
#
# File c:\Users\muhammad.amad\AppData\Local\anaconda3\Lib\site-packages\pandas\core\groupby\grouper.py:1009, in get_grouper(obj, key, axis, level, sort, observed, validate, dropna)
#    1007         in_axis, level, gpr = False, gpr, None
#    1008     else:
# -> 1009         raise KeyError(gpr)
#    1010 elif isinstance(gpr, Grouper) and gpr.key is not None:
#    1011     # Add key to exclusions
#    1012     exclusions.add(gpr.key)
#
# KeyError: 'Tsize'

# %%
sns.barplot(x='Tsize', y='Perc', hue='Survived', data=temp, dodge=True);

# %% [markdown]
# **3.3.3 Consolidating family & friends**

# %%
dftitanic['Group'] = dftitanic[['Tsize', 'Fsize']].max(axis=1)

plt.figure(figsize=(15,6));
sns.countplot(x='Group', hue='Survived', data=dftitanic);

# %%
dftitanic['GrpSize'] = ''
dftitanic.loc[dftitanic['Group']==1, 'GrpSize'] = dftitanic.loc[dftitanic['Group']==1, 'GrpSize'].replace('', 'solo')
dftitanic.loc[dftitanic['Group']==2, 'GrpSize'] = dftitanic.loc[dftitanic['Group']==2, 'GrpSize'].replace('', 'couple')
dftitanic.loc[(dftitanic['Group']<=4) & (dftitanic['Group']>=3), 'GrpSize'] = dftitanic.loc[(dftitanic['Group']<=4) & (dftitanic['Group']>=3), 'GrpSize'].replace('', 'group')
dftitanic.loc[dftitanic['Group']>4, 'GrpSize'] = dftitanic.loc[dftitanic['Group']>4, 'GrpSize'].replace('', 'large group')
dftitanic.head(10)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
# 2            3         1       3
# 3            4         1       1
# 4          138         0       1
# 5            5         0       3
# 6            6         0       3
# 7            7         0       1
# 8            8         0       3
# 9           25         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                             Heikkinen, Miss. Laina  female  26.0      0
# 3       Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                        Futrelle, Mr. Jacques Heath    male  37.0      1
# 5                           Allen, Mr. William Henry    male  35.0      0
# 6                                   Moran, Mr. James    male   NaN      0
# 7                            McCarthy, Mr. Timothy J    male  54.0      0
# 8                     Palsson, Master. Gosta Leonard    male   2.0      3
# 9                      Palsson, Miss. Torborg Danira  female   8.0      3
#
#    Parch            Ticket     Fare Cabin Embarked   Title  Fsize  Tsize  \
# 0      0         A/5 21171   7.2500   NaN        S      Mr      2      1
# 1      0          PC 17599  71.2833   C85        C     Mrs      2      1
# 2      0  STON/O2. 3101282   7.9250   NaN        S    Miss      1      1
# 3      0            113803  53.1000  C123        S     Mrs      2      2
# 4      0            113803  53.1000  C123        S      Mr      2      2
# 5      0            373450   8.0500   NaN        S      Mr      1      1
# 6      0            330877   8.4583   NaN        Q      Mr      1      1
# 7      0             17463  51.8625   E46        S      Mr      1      1
# 8      1            349909  21.0750   NaN        S  Master      5      4
# 9      1            349909  21.0750   NaN        S    Miss      5      4
#
#    Group      GrpSize
# 0      2       couple
# 1      2       couple
# 2      1         solo
# 3      2       couple
# 4      2       couple
# 5      1         solo
# 6      1         solo
# 7      1         solo
# 8      5  large group
# 9      5  large group

# %%
plt.figure(figsize=(15,6));
sns.countplot(x='GrpSize', order=['solo', 'couple', 'group', 'large group'], hue='Survived', data=dftitanic);

# %% [markdown]
# **Task 15:**
# Applying same transformation on **'dfcomp'**

# %% [markdown]
# - FSize task
# - Tsize task
# - Group Column

# %%
#Fsize

#Ticket Size

# Grouping

# %% [markdown]
# Applying the same categories for groups on 'dfcomp'

# %%
dfcomp['GrpSize'] = ''
dfcomp.loc[dfcomp['Group']==1, 'GrpSize'] = dfcomp.loc[dfcomp['Group']==1, 'GrpSize'].replace('', 'solo')
dfcomp.loc[dfcomp['Group']==2, 'GrpSize'] = dfcomp.loc[dfcomp['Group']==2, 'GrpSize'].replace('', 'couple')
dfcomp.loc[(dfcomp['Group']<=4) & (dfcomp['Group']>=3), 'GrpSize'] = dfcomp.loc[(dfcomp['Group']<=4) & (dfcomp['Group']>=3), 'GrpSize'].replace('', 'group')
dfcomp.loc[dfcomp['Group']>4, 'GrpSize'] = dfcomp.loc[dfcomp['Group']>4, 'GrpSize'].replace('', 'large group')
dfcomp.head()

# %% [markdown]
# ### 3.4 Effect of Fare

# %% [markdown]
# **Task 16:**
# Check the null values of fare

# %%
# Write code here
dftitanic['Fare'].isnull().count()
# Out:
# 891

# %%
plt.subplots(figsize=(15,6))
sns.distplot(dftitanic['Fare']);
# Out:
# C:\Users\muhammad.amad\AppData\Local\Temp\ipykernel_17856\2336507706.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(dftitanic['Fare']);

# %%
dftitanic[dftitanic['Fare'] < 0]
# Out:
# Empty DataFrame
# Columns: [PassengerId, Survived, Pclass, Name, Sex, Age, SibSp, Parch, Ticket, Fare, Cabin, Embarked, Title, Fsize, Tsize, Group, GrpSize]
# Index: []

# %%
dftitanic[dftitanic['GrpSize']=='couple']
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 3              4         1       1
# 4            138         0       1
# 15            10         1       2
# ..           ...       ...     ...
# 834          804         1       3
# 865          854         1       1
# 866          856         1       3
# 870          862         0       2
# 874          867         1       2
#
#                                                   Name     Sex    Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.00      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.00      1
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.00      1
# 4                          Futrelle, Mr. Jacques Heath    male  37.00      1
# 15                 Nasser, Mrs. Nicholas (Adele Achem)  female  14.00      1
# ..                                                 ...     ...    ...    ...
# 834                    Thomas, Master. Assad Alexander    male   0.42      0
# 865                          Lines, Miss. Mary Conover  female  16.00      0
# 866                         Aks, Mrs. Sam (Leah Rosen)  female  18.00      0
# 870                        Giles, Mr. Frederick Edward    male  21.00      1
# 874                       Duran y More, Miss. Asuncion  female  27.00      1
#
#      Parch         Ticket     Fare Cabin Embarked   Title  Fsize  Tsize  \
# 0        0      A/5 21171   7.2500   NaN        S      Mr      2      1
# 1        0       PC 17599  71.2833   C85        C     Mrs      2      1
# 3        0         113803  53.1000  C123        S     Mrs      2      2
# 4        0         113803  53.1000  C123        S      Mr      2      2
# 15       0         237736  30.0708   NaN        C     Mrs      2      2
# ..     ...            ...      ...   ...      ...     ...    ...    ...
# 834      1           2625   8.5167   NaN        C  Master      2      1
# 865      1       PC 17592  39.4000   D28        S    Miss      2      1
# 866      1         392091   9.3500   NaN        S     Mrs      2      1
# 870      0          28134  11.5000   NaN        S      Mr      2      1
# 874      0  SC/PARIS 2149  13.8583   NaN        C    Miss      2      1
#
#      Group GrpSize
# 0        2  couple
# 1        2  couple
# 3        2  couple
# 4        2  couple
# 15       2  couple
# ..     ...     ...
# 834      2  couple
# 865      2  couple
# 866      2  couple
# 870      2  couple
# 874      2  couple
#
# [185 rows x 17 columns]

# %%
dftitanic[dftitanic['Fare'] == 0]
# Out:
#      PassengerId  Survived  Pclass                              Name   Sex  \
# 266          180         0       3               Leonard, Mr. Lionel  male
# 267          272         1       3      Tornquist, Mr. William Henry  male
# 268          303         0       3   Johnson, Mr. William Cahoone Jr  male
# 269          598         0       3               Johnson, Mr. Alfred  male
# 366          264         0       1             Harrison, Mr. William  male
# 386          278         0       2       Parkes, Mr. Francis "Frank"  male
# 387          414         0       2    Cunningham, Mr. Alfred Fleming  male
# 388          467         0       2             Campbell, Mr. William  male
# 592          482         0       2  Frost, Mr. Anthony Wood "Archie"  male
# 715          634         0       1     Parr, Mr. William Henry Marsh  male
# 743          675         0       2        Watson, Mr. Ennis Hastings  male
# 786          733         0       2              Knight, Mr. Robert J  male
# 837          807         0       1            Andrews, Mr. Thomas Jr  male
# 843          816         0       1                  Fry, Mr. Richard  male
# 849          823         0       1   Reuchlin, Jonkheer. John George  male
#
#       Age  SibSp  Parch  Ticket  Fare Cabin Embarked       Title  Fsize  \
# 266  36.0      0      0    LINE   0.0   NaN        S          Mr      1
# 267  25.0      0      0    LINE   0.0   NaN        S          Mr      1
# 268  19.0      0      0    LINE   0.0   NaN        S          Mr      1
# 269  49.0      0      0    LINE   0.0   NaN        S          Mr      1
# 366  40.0      0      0  112059   0.0   B94        S          Mr      1
# 386   NaN      0      0  239853   0.0   NaN        S          Mr      1
# 387   NaN      0      0  239853   0.0   NaN        S          Mr      1
# 388   NaN      0      0  239853   0.0   NaN        S          Mr      1
# 592   NaN      0      0  239854   0.0   NaN        S          Mr      1
# 715   NaN      0      0  112052   0.0   NaN        S          Mr      1
# 743   NaN      0      0  239856   0.0   NaN        S          Mr      1
# 786   NaN      0      0  239855   0.0   NaN        S          Mr      1
# 837  39.0      0      0  112050   0.0   A36        S          Mr      1
# 843   NaN      0      0  112058   0.0  B102        S          Mr      1
# 849  38.0      0      0   19972   0.0   NaN        S  Rare Title      1
#
#      Tsize  Group GrpSize
# 266      4      4   group
# 267      4      4   group
# 268      4      4   group
# 269      4      4   group
# 366      1      1    solo
# 386      3      3   group
# 387      3      3   group
# 388      3      3   group
# 592      1      1    solo
# 715      1      1    solo
# 743      1      1    solo
# 786      1      1    solo
# 837      1      1    solo
# 843      1      1    solo
# 849      1      1    solo

# %%
dftitanic.loc[(dftitanic['Fare'] == 0) & (dftitanic['Pclass'] == 1), 'Fare'] = dftitanic[dftitanic['Pclass'] == 1]['Fare'].median()
dftitanic.loc[(dftitanic['Fare'] == 0) & (dftitanic['Pclass'] == 2), 'Fare'] = dftitanic[dftitanic['Pclass'] == 2]['Fare'].median()
dftitanic.loc[(dftitanic['Fare'] == 0) & (dftitanic['Pclass'] == 3), 'Fare'] = dftitanic[dftitanic['Pclass'] == 3]['Fare'].median()

# %%
dftitanic[dftitanic['Fare']==0]
# Out:
# Empty DataFrame
# Columns: [PassengerId, Survived, Pclass, Name, Sex, Age, SibSp, Parch, Ticket, Fare, Cabin, Embarked, Title, Fsize, Tsize, Group, GrpSize]
# Index: []

# %% [markdown]
# Assigning categories to fare

# %%
dftitanic['FareCat'] = ''
dftitanic.loc[dftitanic['Fare']<=10, 'FareCat'] = '0-10'
dftitanic.loc[(dftitanic['Fare']>10) & (dftitanic['Fare']<=25), 'FareCat'] = '10-25'
dftitanic.loc[(dftitanic['Fare']>25) & (dftitanic['Fare']<=40), 'FareCat'] = '25-40'
dftitanic.loc[(dftitanic['Fare']>40) & (dftitanic['Fare']<=70), 'FareCat'] = '40-70'
dftitanic.loc[(dftitanic['Fare']>70) & (dftitanic['Fare']<=100), 'FareCat'] = '70-100'
dftitanic.loc[dftitanic['Fare']>100, 'FareCat'] = '100+'
dftitanic[['Fare', 'FareCat']].head()
# Out:
#       Fare FareCat
# 0   7.2500    0-10
# 1  71.2833  70-100
# 2   7.9250    0-10
# 3  53.1000   40-70
# 4  53.1000   40-70

# %%
plt.subplots(figsize=(15,6))
sns.countplot(x='FareCat', order=['0-10', '10-25', '25-40', '40-70', '70-100', '100+'], hue='Survived', data=dftitanic);

# %% [markdown]
# **Task 17:**
# Applying same changes on **'dfcomp'**

# %% [markdown]
# - First check if Fair is zero
# - Then replace it with median fare of Pclass

# %%
#Write code to check the Fair

# %%
#write the code to find the median

# %% [markdown]
# **Task 18:**
# Make categories of fare as following:
#
# - If Fare is <=10, then category= '0-10'
# - If Fare is >10 and Fare is <=25, then category= '10-25'
# - If Fare is >25 and Fare is <=40, then category= '25-40'
# - If Fare is >40 and Fare is <=70, then category= '40-70'
# - If Fare is >70 and Fare is <=100, then category= '70-100'
# - If Fare is >100, then category= '100+'

# %%
#Write the code for Assigning Categories
dfcomp['FareCat'] = ''




dfcomp[['Fare', 'FareCat']].head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# d:\python\EDA _ Seaborn\EDA SEABORN-1.ipynb Cell 121 line 2
#       <a href='vscode-notebook-cell:/d%3A/python/EDA%20_%20Seaborn/EDA%20SEABORN-1.ipynb#Y224sZmlsZQ%3D%3D?line=0'>1</a> #Write the code for Assigning Categories
# ----> <a href='vscode-notebook-cell:/d%3A/python/EDA%20_%20Seaborn/EDA%20SEABORN-1.ipynb#Y224sZmlsZQ%3D%3D?line=1'>2</a> dfcomp['FareCat'] = ''
#       <a href='vscode-notebook-cell:/d%3A/python/EDA%20_%20Seaborn/EDA%20SEABORN-1.ipynb#Y224sZmlsZQ%3D%3D?line=6'>7</a> dfcomp[['Fare', 'FareCat']].head()
#
# NameError: name 'dfcomp' is not defined

# %% [markdown]
# ### 3.5 Effect of Embarked variable
#
# _C = Cherbourg(France), Q = Queenstown(Ireland), S = Southampton(England)_

# %% [markdown]
# **Task 19:**
# Make the countplot for embarkments

# %%
# Write the code here

# %% [markdown]
# ***Engineered Features***

# %%
dftitanic.head(2)
# Out:
#    PassengerId  Survived  Pclass  \
# 0            1         0       3
# 1            2         1       1
#
#                                                 Name     Sex   Age  SibSp  \
# 0                            Braund, Mr. Owen Harris    male  22.0      1
# 1  Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
#
#    Parch     Ticket     Fare Cabin Embarked Title  Fsize  Tsize  Group  \
# 0      0  A/5 21171   7.2500   NaN        S    Mr      2      1      2
# 1      0   PC 17599  71.2833   C85        C   Mrs      2      1      2
#
#   GrpSize FareCat
# 0  couple    0-10
# 1  couple  70-100

# %% [markdown]
# **Task 20:**
# Check the engineered features for dfcomp

# %%
#Write the code here

# %% [markdown]
# ## 4. Missing Values

# %% [markdown]
# ### 4.1 Age

# %%
sns.kdeplot(dftitanic[dftitanic['Survived'] == 0]['Age'].dropna(), shade=True,label="Not survived");
sns.kdeplot(dftitanic[dftitanic['Survived'] == 1]['Age'].dropna(), shade=True,label="Survived");
# Out:
# C:\Users\muhammad.amad\AppData\Local\Temp\ipykernel_17856\1782922720.py:1: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(dftitanic[dftitanic['Survived'] == 0]['Age'].dropna(), shade=True,label="Not survived");
# C:\Users\muhammad.amad\AppData\Local\Temp\ipykernel_17856\1782922720.py:2: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(dftitanic[dftitanic['Survived'] == 1]['Age'].dropna(), shade=True,label="Survived");

# %%
temp = dftitanic[dftitanic['Age'].isnull() == False]

# %%
temp
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4            138         0       1
# ..           ...       ...     ...
# 886          885         0       3
# 887          887         0       2
# 888          888         1       1
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                          Futrelle, Mr. Jacques Heath    male  37.0      1
# ..                                                 ...     ...   ...    ...
# 886                             Sutehall, Mr. Henry Jr    male  25.0      0
# 887                              Montvila, Rev. Juozas    male  27.0      0
# 888                       Graham, Miss. Margaret Edith  female  19.0      0
# 889                              Behr, Mr. Karl Howell    male  26.0      0
# 890                                Dooley, Mr. Patrick    male  32.0      0
#
#      Parch            Ticket     Fare Cabin Embarked       Title  Fsize  \
# 0        0         A/5 21171   7.2500   NaN        S          Mr      2
# 1        0          PC 17599  71.2833   C85        C         Mrs      2
# 2        0  STON/O2. 3101282   7.9250   NaN        S        Miss      1
# 3        0            113803  53.1000  C123        S         Mrs      2
# 4        0            113803  53.1000  C123        S          Mr      2
# ..     ...               ...      ...   ...      ...         ...    ...
# 886      0   SOTON/OQ 392076   7.0500   NaN        S          Mr      1
# 887      0            211536  13.0000   NaN        S  Rare Title      1
# 888      0            112053  30.0000   B42        S        Miss      1
# 889      0            111369  30.0000  C148        C          Mr      1
# 890      0            370376   7.7500   NaN        Q          Mr      1
#
#      Tsize  Group GrpSize FareCat
# 0        1      2  couple    0-10
# 1        1      2  couple  70-100
# 2        1      1    solo    0-10
# 3        2      2  couple   40-70
# 4        2      2  couple   40-70
# ..     ...    ...     ...     ...
# 886      1      1    solo    0-10
# 887      1      1    solo   10-25
# 888      1      1    solo   25-40
# 889      1      1    solo   25-40
# 890      1      1    solo    0-10
#
# [714 rows x 18 columns]

# %%
sns.set_context('poster')
sns.catplot(kind='box', x='Age', col='Title', row='Pclass', data=temp);

# %%
for t in dftitanic['Title'].unique():
    for p in dftitanic['Pclass'].unique():
        dftitanic.loc[(dftitanic['Title'] == t) & (dftitanic['Pclass'] == p) & (dftitanic['Age'].isnull()), 'Age'] = dftitanic.loc[(dftitanic['Title'] == t) & (dftitanic['Pclass'] == p), 'Age'].median()

# %%
plt.subplots(figsize=(10,6))
sns.kdeplot(dftitanic[dftitanic['Survived'] == 0]['Age'], shade=True,label='Not Survived');
sns.kdeplot(dftitanic[dftitanic['Survived'] == 1]['Age'], shade=True,label='Survived');
# Out:
# C:\Users\muhammad.amad\AppData\Local\Temp\ipykernel_17856\1346470427.py:2: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(dftitanic[dftitanic['Survived'] == 0]['Age'], shade=True,label='Not Survived');
# C:\Users\muhammad.amad\AppData\Local\Temp\ipykernel_17856\1346470427.py:3: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(dftitanic[dftitanic['Survived'] == 1]['Age'], shade=True,label='Survived');

# %% [markdown]
# **Task 21:**
# Check if there is any null in the column 'Age'

# %%
#Write code here

# %% [markdown]
# Creating Age categories

# %%
dftitanic['AgeCat']=''
dftitanic.loc[ dftitanic['Age'] <= 16, 'AgeCat'] = '0-16'
dftitanic.loc[(dftitanic['Age'] > 16) & (dftitanic['Age'] <= 32), 'AgeCat'] = '16-32'
dftitanic.loc[(dftitanic['Age'] > 32) & (dftitanic['Age'] <= 48), 'AgeCat'] = '32-48'
dftitanic.loc[(dftitanic['Age'] > 48) & (dftitanic['Age'] <= 64), 'AgeCat'] = '48-64'
dftitanic.loc[ dftitanic['Age'] > 64, 'AgeCat']= '64+'

# %% [markdown]
# **Task 22:**
# Replace missing Age & Fair values in **'dfcomp'**

# %%
#Write the code for filling in the values with median

# %% [markdown]
# Checking the null values in 'Age' column again!

# %%
dfcomp['Age'].isnull().sum()

# %% [markdown]
# Checking the **pclass** and **title** for which the null value exists

# %%
dfcomp.loc[(dfcomp['Age'].isnull()),'Pclass':'Title']

# %% [markdown]
# Filling in the missing value with the median of the specific **pclass**

# %%
dfcomp.loc[(dfcomp['Age'].isnull()) & (dfcomp['Pclass'] == 3) & (dfcomp['Title'] == 'Rare Title'), 'Age'] = dfcomp.loc[(dfcomp['Title'] == 'Rare Title') & (dfcomp['Pclass'] == 3), 'Age'].median()

# %% [markdown]
# **Task 23:**
# Repeat the above procedure for **'Fare'**

# %%
#Write the code to check if there is any null value

# %%
#Write code to check the pclass and title for which the null value exists

# %%
#Write code to fill in the missing value

# %%
#Assigning the category to the newly added value
dfcomp.loc[dfcomp['Fare']<=10, 'FareCat'] = '0-10'

# %% [markdown]
# **Task 24:** Make Categories for Age as following
# - If Age is <=16, then category= '0-16'
# - If Age is >16 and Fare is <=32, then category= '16-32'
# - If Age is >32 and Fare is <=48, then category= '32-48'
# - If Age is >48 and Fare is <=64, then category= '48-64'
# - If Agee is >64, then category= '64+'

# %%
#Write the code here

# %% [markdown]
# ### 4.2 Embarkment and null values

# %%
dftitanic.describe(include='O')

# %%
dftitanic['Embarked'].isnull().sum()

# %%
dftitanic.loc[(dftitanic['Embarked'].isnull()),'Embarked']='S'

# %% [markdown]
# **Task 25:** Check the nulls in 'Embarked' for **'dfcomp'** and see if any value needs to be replaced

# %%
# Write code to check the nulls in Embarked

# %%
#Write the code here to replace

# %% [markdown]
# ### 4.3 Dropping Cabin

# %% [markdown]
# Defining the cabin type

# %%
dftitanic['CabinType'] = dftitanic['Cabin'].str[0]

# %%
plt.figure(figsize=(15,6))
sns.countplot(x='CabinType', hue='Survived', data=dftitanic);

# %% [markdown]
# Dropping Cabin

# %%
dftitanic.groupby(['CabinType', 'Pclass'])['Pclass'].count()
# Out:
# CabinType  Pclass
# A          1         15
# B          1         47
# C          1         59
# D          1         29
#            2          4
# E          1         25
#            2          4
#            3          3
# F          2          8
#            3          5
# G          3          4
# T          1          1
# Name: Pclass, dtype: int64

# %%
dftitanic.drop('Cabin',inplace=True)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# d:\python\EDA _ Seaborn\EDA SEABORN-1.ipynb Cell 169 line 1
# ----> <a href='vscode-notebook-cell:/d%3A/python/EDA%20_%20Seaborn/EDA%20SEABORN-1.ipynb#Y322sZmlsZQ%3D%3D?line=0'>1</a> dftitanic.drop('Cabin',inplace=True)
#
# File c:\Users\muhammad.amad\AppData\Local\anaconda3\Lib\site-packages\pandas\util\_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# File c:\Users\muhammad.amad\AppData\Local\anaconda3\Lib\site-packages\pandas\core\frame.py:5399, in DataFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    5251 @deprecate_nonkeyword_arguments(version=None, allowed_args=["self", "labels"])
#    5252 def drop(  # type: ignore[override]
#    5253     self,
#    (...)
#    5260     errors: IgnoreRaise = "raise",
#    5261 ) -> DataFrame | None:
#    5262     """
#    5263     Drop specified labels from rows or columns.
#    5264
#    (...)
#    5397             weight  1.0     0.8
#    5398     """
# -> 5399     return super().drop(
#    5400         labels=labels,
#    5401         axis=axis,
#    5402         index=index,
#    5403         columns=columns,
#    5404         level=level,
#    5405         inplace=inplace,
#    5406         errors=errors,
#    5407     )
#
# File c:\Users\muhammad.amad\AppData\Local\anaconda3\Lib\site-packages\pandas\util\_decorators.py:331, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     325 if len(args) > num_allow_args:
#     326     warnings.warn(
#     327         msg.format(arguments=_format_argument_list(allow_args)),
#     328         FutureWarning,
#     329         stacklevel=find_stack_level(),
#     330     )
# --> 331 return func(*args, **kwargs)
#
# File c:\Users\muhammad.amad\AppData\Local\anaconda3\Lib\site-packages\pandas\core\generic.py:4505, in NDFrame.drop(self, labels, axis, index, columns, level, inplace, errors)
#    4503 for axis, labels in axes.items():
#    4504     if labels is not None:
# -> 4505         obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4507 if inplace:
#    4508     self._update_inplace(obj)
#
# File c:\Users\muhammad.amad\AppData\Local\anaconda3\Lib\site-packages\pandas\core\generic.py:4546, in NDFrame._drop_axis(self, labels, axis, level, errors, only_slice)
#    4544         new_axis = axis.drop(labels, level=level, errors=errors)
#    4545     else:
# -> 4546         new_axis = axis.drop(labels, errors=errors)
#    4547     indexer = axis.get_indexer(new_axis)
#    4549 # Case for non-unique axis
#    4550 else:
#
# File c:\Users\muhammad.amad\AppData\Local\anaconda3\Lib\site-packages\pandas\core\indexes\base.py:6934, in Index.drop(self, labels, errors)
#    6932 if mask.any():
#    6933     if errors != "ignore":
# -> 6934         raise KeyError(f"{list(labels[mask])} not found in axis")
#    6935     indexer = indexer[~mask]
#    6936 return self.delete(indexer)
#
# KeyError: "['Cabin'] not found in axis"

# %% [markdown]
# **Task 26:**
# Drop cabin from dfcomp

# %%
#Write the code here

# %% [markdown]
# **Task 27:** Check missing values in dftitanic

# %%
#Write the code here

# %% [markdown]
# **Task 28:** Checking missing values in **'dfcomp'**

# %%
#wrtie the code here

# %% [markdown]
# ## 5. Feature Selection

# %%
sns.set_context('poster')

# %%
sns.set_context('poster')
plt.figure(figsize=(15,6))
cor = dftitanic.drop('PassengerId',axis=1).corr()
sns.heatmap(cor, annot=True, fmt='.1g');
# Out:
# C:\Users\muhammad.amad\AppData\Local\Temp\ipykernel_17856\3144462343.py:3: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   cor = dftitanic.drop('PassengerId',axis=1).corr()

# %% [markdown]
# The above heat map shows the corelation of different columns with eachother. A heatmap often helps to view the corelation as seen above. Looking at the above heatmap we can conclude that which attributes or columns are corelated and and can be removed to get a better shaped dataset.
#
# The following points are to be considered for dropping the columns
#
# - **'Group'** holds a corelation of 0.9 with **'Fsize'** and **'Tsize'**. So we will remove **'Group'** and **'Tsize'** because related data can be found in **'GrpSize'**.
# - **'Fsize'** still has a corelation of 0.9  with **'SibSp'** and 0.8 with **'Parch'**.So we will remove 'Fsize' because **'SibSp'** and **'Parch'** are providing the required information.
# - The **'Name'** column can also be removed because **'Title'** has been extracted.
# - Similarly **'Age'** and **'Fare'** can also be removed because **'AgeCat'** and **'FareCat'** provide the related information.
#
# So the final columns to be dropped are: 'Name','Age','Fare','Ticket','Fsize','Tsize' and 'Group'

# %%
drop_features = ['Name','Age','Fare','Ticket','Fsize','Tsize','Group']

# %% [markdown]
# Selecting final features

# %%
dftitanic.drop(drop_features,axis=1,inplace=True)

# %% [markdown]
# **Task 29:** Draw the heatmap as shown above and find the co-relation. Also check which features are to be removed.

# %%
#Write the code for heat map here

# %% [markdown]
# **Task 30:** Drop the features in dfcomp using **drop_features**

# %%
#Write the code to drop the columns here

# %% [markdown]
# Exporting final dataset in csv file

# %%
dftitanic.to_csv('titanic_clean.csv',index=False)

# %% [markdown]
# **Task 31:** Export **'dfcomp'** into csv file

# %%
#Write code here
